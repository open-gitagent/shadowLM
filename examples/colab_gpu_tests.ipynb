# %% [markdown]
# # shadowLM — CUDA verification suite
#
# Runs every GPU-only path the SDK has: 4-bit (bitsandbytes), fused optimizers,
# wrapper device placement (retrieval experts / bottleneck adapters), online
# GRPO with generation in the loop, DPO, the 12-method sweep, and the capture
# proxy. Pass/fail summary at the end.
#
# **Runtime → Change runtime type → GPU** (T4 is enough; ~10–15 min).

# %%
# Get the code — pick ONE:
# (a) from your git remote:
# !git clone https://github.com/<you>/shadowLM.git
# (b) or upload shadowLM.zip via the Files sidebar, then:
# !unzip -q shadowLM.zip
# %cd shadowLM
# !pip install -q -e '.[torch]' bitsandbytes sentence-transformers

# %%
# !python tests/gpu/test_cuda.py

# %% [markdown]
# Exit code 0 = all passed (skips are fine — `flash_attn` is optional).
# If anything fails, paste the summary table back into the chat.
